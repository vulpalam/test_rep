# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import sentiment_mod as s

#consumer key, consumer secret, access token, access secret.
ckey="GET FROM FILE"
csecret="GET FROM FILE"
atoken="GET FROM FILE"
asecret="GET FROM FILE"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        time.sleep(1)
        
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)
        
        if confidence*100 >= 80:
            output = open("twitter-out.txt","a")
            output.write(sentiment_value)
            output.write('\n')
            output.close()
            
        return True

    def on_error(self, status):
        print (status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["Earth"])
# Out:
# RT @theTelluris: Terry Virts นักบินอวกาศของ NASA บอกว่า เขาสามารถช่วยให้ B.o.B. ประหยัดเงินเรื่องพิสูจน์โลกแบนได้ โลกนี้น่ะกลม เพราะ…  neg 1.0
# We thought this was .@DoRtChristians. We're convinced this is something they'd do. After all they want to sue @CNN https://t.co/I56pW5qsp0 neg 1.0
# Me gustó un video de @YouTube https://t.co/6pWP1OVPQf (New Mod Menu) Last Day on Earth: Survival 1.5.9 &amp; 1.5.10 - Unlimited Money, neg 1.0
# RT @Scripture_Truth: I know that my redeemer lives, and that in the end he will stand on the earth. -Job 19:25 neg 1.0
# Я  рак! БЛ  #GoogleDoodle. https://t.co/wxxv1T0AGm neg 1.0
# RT @Country_Words: Until our song is over, til the stars all fade to black, I’m gonna love you to the ends of the earth, to the moon and ba… neg 1.0
# RT @FameLukez: Earth is flat if it weren't I'd fall of and die brain dead scientists @NASA @CNN #TuesdayThoughts neg 1.0
# @bobatl @bobatl since you believe the earth is flat do you not trust airplanes? neg 1.0
# earth go hard neg 1.0
# RT @JoeAgneya: "If the findings are accurate, it means life took hold on Earth just a geological second after its formation some 4…  neg 1.0
# There are some people that no matter how many times I freak the fuck out on them it's just not enough. Ur just such scum of the earth neg 1.0
# RT @thereaIbanksy: Earth is no longer thriving. https://t.co/wTLiJbvLkP neg 1.0
# RT @WhoIsTreyMorgan: Cool bro, I'll give you $5 to watch you prove yourself wrong... @bobatl is raising money to prove #FlatEarth theory
# ht… neg 1.0
# RT @Blike_Dante: “You know I like my butts how I like my earth baby.” https://t.co/LzPiU36aR9 neg 1.0
# Matic is a great player why on earth did Chelsea sell us him neg 1.0
# RT @FameLukez: Earth is flat if it weren't I'd fall of and die brain dead scientists @NASA @CNN #TuesdayThoughts neg 1.0
# RT @earth: High above the Canadian Rockies https://t.co/hYcM8xu1AE neg 1.0
# @CBSThisMorning @vladduthiersCBS @DPartlyCloudy Whenever one suggests"Global Warming" man made especially, ask if t… https://t.co/NOnFAao3oF neg 1.0
# RT @inspirestagram: The best thing on earth, is sharing a laugh with someone you love. neg 1.0
# RT @chuckwoolery: I am sick of all the #Malcontents on the Left telling me why I should Hate America. I believe America is the greatest cou… neg 1.0
# RT @ToddWhiteLC: I believe we are headed for an awakening in the Church---
# waking up to Her created value and purpose on this earth! neg 1.0
# @AmericanAtheist Atheists are no better than the Flat Earth Society.  Idiots that cannot see engineered creation al… https://t.co/oyeENph7qp neg 1.0
# Been watching the football. How on Earth did England win that match? neg 1.0
# RT @nowthisnews: B.o.B wants to launch satellites into space to prove Earth is flat https://t.co/ETCPgJ54l4 neg 1.0
# RT @totalgolfmove: Golf is wierd bc you can go from striking it purely to hooking it off the face of the Earth with one simple millimeter s… neg 1.0
# RT @nowthisnews: B.o.B wants to launch satellites into space to prove Earth is flat https://t.co/ETCPgJ54l4 neg 1.0
# RT @ImperiousLex: “And you get to Darwinian evolution and you find out, we're not special on this Earth we're just one among other li…  neg 1.0
# RT @NewsHour: OSIRIS-REx probe snaps Earth photo on way to space mining adventure https://t.co/USeydojBAz neg 1.0
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# //anaconda/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     577                 if len(mvb) <= chunk_left:
# --> 578                     n = self._safe_readinto(mvb)
#     579                     self.chunk_left = chunk_left - n
#
# //anaconda/lib/python3.5/http/client.py in _safe_readinto(self, b)
#     624             if not n:
# --> 625                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     626             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     297             try:
# --> 298                 yield
#     299
#
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# //anaconda/lib/python3.5/http/client.py in read(self, amt)
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#
# //anaconda/lib/python3.5/http/client.py in readinto(self, b)
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#
# //anaconda/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     588         except IncompleteRead:
# --> 589             raise IncompleteRead(bytes(b[0:total_bytes]))
#     590
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-2-e0bbc951e7d8> in <module>()
#      37
#      38 twitterStream = Stream(auth, listener())
# ---> 39 twitterStream.filter(track=["Earth"])
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# //anaconda/lib/python3.5/site-packages/tweepy/streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     395                         # raised during streaming, so all calls with incorrect
#     396                         # Content-Length are caught.
# --> 397                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     398
#     399         if data:
#
# //anaconda/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     314             except (HTTPException, SocketError) as e:
#     315                 # This includes IncompleteRead.
# --> 316                 raise ProtocolError('Connection broken: %r' % e, e)
#     317
#     318             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))
